% %% [markdown]
% <h1>Table of Contents<span class="tocSkip"></span></h1>
% <div class="toc"><ul class="toc-item"><li><span><a href="#Exercises:-Due-Friday,-Dec-5-by-5PM" data-toc-modified-id="Exercises:-Due-Friday,-Dec-5-by-5PM-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exercises: Due Friday, Dec 5 by 5PM</a></span><ul class="toc-item"><li><span><a href="#Problem-1" data-toc-modified-id="Problem-1-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Problem 1</a></span></li><li><span><a href="#Problem-2" data-toc-modified-id="Problem-2-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Problem 2</a></span></li><li><span><a href="#Problem-3" data-toc-modified-id="Problem-3-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Problem 3</a></span></li></ul></li></ul></div>

% %% [markdown]
% # Exercises: Due Friday, Dec 5 by 5PM
%
% Answer the following questions:

% %% [markdown]
% ## Problem 1
%
% Find the gain and phase margins for the following system under proportional control by hand. Show any and all hand calculations, and then use MATLAB to check using the "margin" command (I would suggest you use "actual" MATLAB to do this, rather than doing it in the Jupyter notebook. Sometimes calling the margin command in the notebook gives weird results). You may print or screenshot a Bode plot to aid you in your "hand calculations" if you like.
%
% $$P(s) = \frac{1000}{(s+10)(s^2+2s+10)}$$

% %% [markdown]
% YOUR ANSWER HERE

% %%
% YOUR CODE HERE
error('No Answer Given!')

% %% [markdown]
% ## Problem 2
%
% Find the gain and phase margins for the same plant transfer function above, but under proportional-integral control with a control zero at $s=-20$. Show any and all hand calculations, and then use MATLAB to check using the "margin" command (I would suggest you use "actual" MATLAB to do this, rather than doing it in the Jupyter notebook. Sometimes calling the margin command in the notebook gives weird results). You may print or screenshot a Bode plot to aid you in your "hand calculations" if you like.

% %% [markdown]
% YOUR ANSWER HERE

% %%
% YOUR CODE HERE
error('No Answer Given!')

% %% [markdown]
% ## Problem 3
%
% Briefly discuss the qualitative differences between these two control strategies for this plant (P vs. PI), using *everything* you know about controller design. Comment on the relative stability, achievable eigenvalues, maximum root locus gain to maintain a stable system, steady state error, etc. Show any work that you use to support your analysis.

% %% [markdown]
% YOUR ANSWER HERE
