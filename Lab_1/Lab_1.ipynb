# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Challenge" data-toc-modified-id="Challenge-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Challenge</a></span></li><li><span><a href="#Disciplined-Process" data-toc-modified-id="Disciplined-Process-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Disciplined Process</a></span></li><li><span><a href="#Model-Development:-DC-Motor" data-toc-modified-id="Model-Development:-DC-Motor-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><em>Model Development:</em> DC Motor</a></span></li><li><span><a href="#Model-Development:-Relay" data-toc-modified-id="Model-Development:-Relay-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><em>Model Development:</em> Relay</a></span></li><li><span><a href="#Model-Development:-DC-Motor-&amp;-Relay" data-toc-modified-id="Model-Development:-DC-Motor-&amp;-Relay-5"><span class="toc-item-num">5&nbsp;&nbsp;</span><em>Model Development:</em> DC Motor &amp; Relay</a></span></li><li><span><a href="#Model-Validation:-DC-Motor-&amp;-Relay" data-toc-modified-id="Model-Validation:-DC-Motor-&amp;-Relay-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><em>Model Validation:</em> DC Motor &amp; Relay</a></span><ul class="toc-item"><li><span><a href="#WORKSTATION-SETUP" data-toc-modified-id="WORKSTATION-SETUP-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>WORKSTATION SETUP</a></span></li><li><span><a href="#Experimental-Validation" data-toc-modified-id="Experimental-Validation-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Experimental Validation</a></span></li></ul></li><li><span><a href="#Controller-Design:-DC-Motor-Speed-and-Direction" data-toc-modified-id="Controller-Design:-DC-Motor-Speed-and-Direction-7"><span class="toc-item-num">7&nbsp;&nbsp;</span><em>Controller Design:</em> DC Motor Speed and Direction</a></span><ul class="toc-item"><li><span><a href="#Model-Development:-Pulse-Width-Modulation" data-toc-modified-id="Model-Development:-Pulse-Width-Modulation-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span><em>Model Development:</em> Pulse Width Modulation</a></span></li><li><span><a href="#Model-Validation-Pulse-Width-Modulation" data-toc-modified-id="Model-Validation-Pulse-Width-Modulation-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span><em>Model Validation</em> Pulse Width Modulation</a></span></li><li><span><a href="#Model-Development:-Transistor-Model" data-toc-modified-id="Model-Development:-Transistor-Model-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span><em>Model Development:</em> Transistor Model</a></span></li><li><span><a href="#Model-Validation:-npn-Transistor" data-toc-modified-id="Model-Validation:-npn-Transistor-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span><em>Model Validation:</em> npn Transistor</a></span></li></ul></li><li><span><a href="#Controller-Design:-H-Bridge-Circuit" data-toc-modified-id="Controller-Design:-H-Bridge-Circuit-8"><span class="toc-item-num">8&nbsp;&nbsp;</span><em>Controller Design:</em> H-Bridge Circuit</a></span></li><li><span><a href="#Controller-Validation:-DC-Motor-Direction" data-toc-modified-id="Controller-Validation:-DC-Motor-Direction-9"><span class="toc-item-num">9&nbsp;&nbsp;</span><em>Controller Validation:</em> DC Motor Direction</a></span></li><li><span><a href="#Controller-Validation:-DC-Motor-Direction" data-toc-modified-id="Controller-Validation:-DC-Motor-Direction-10"><span class="toc-item-num">10&nbsp;&nbsp;</span><em>Controller Validation:</em> DC Motor Direction</a></span></li><li><span><a href="#Controller-Validation:-DC-Motor-Speed" data-toc-modified-id="Controller-Validation:-DC-Motor-Speed-11"><span class="toc-item-num">11&nbsp;&nbsp;</span><em>Controller Validation:</em> DC Motor Speed</a></span></li><li><span><a href="#Model-Development:-Switches" data-toc-modified-id="Model-Development:-Switches-12"><span class="toc-item-num">12&nbsp;&nbsp;</span><em>Model Development:</em> Switches</a></span><ul class="toc-item"><li><span><a href="#Model-Validation:-Switches" data-toc-modified-id="Model-Validation:-Switches-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span><em>Model Validation:</em> Switches</a></span></li></ul></li><li><span><a href="#Controller-Design:-Parking-Gate" data-toc-modified-id="Controller-Design:-Parking-Gate-13"><span class="toc-item-num">13&nbsp;&nbsp;</span><em>Controller Design:</em> Parking Gate</a></span></li><li><span><a href="#Controller-Validation:-Parking-Gate" data-toc-modified-id="Controller-Validation:-Parking-Gate-14"><span class="toc-item-num">14&nbsp;&nbsp;</span><em>Controller Validation:</em> Parking Gate</a></span></li></ul></div>

# %% [markdown]
# # Challenge
#
# Since you will be using a Zumo for your projects, you will eventually need to be able to model and control the Zumo's motors.  However, it is difficult to learn how to do that when the Zumo keeps driving away!  So you will use the same motors that are used in the Zumo to run the robot traffic gates that you are working with in the [Week 1 Monday Exercise.](../W01A_FSM_DiagramsTables/W01A_FSM_DiagramsTables.ipynb#Challenge:-Zumo-Intersection)
# <img src="attachment:image-2.png" width="600">
#
# Thus the current challenge is to operate a physical motor-driven gate so that by pressing a button the motor will turn and raise the gate until it contacts the "up" limit switch, stopping the motor. When the button is pressed again, the motor will need to turn on and drive the gate down until the "down" limit switch is pressed, stopping the motor again.

# %% [markdown]
# # Disciplined Process
#
# There is no expectation that you know enough at this moment to meet the challenge described above, but approaching it in managable pieces will get you there.  As was discussed in the [Week 01 Monday](../W01A_FSM_DiagramsTables/W01A_FSM_DiagramsTables.ipynb#Challenge:-Zumo-Intersection) notebook, we will follow the same high-level **Disciplined Process** here.
#
# ![image-4.png](attachment:image-4.png)
#
# We won't always have a lot of detail in each of these steps, and we may take detours and backtracks along the way as we discover that we need to modify our model scope or change our approach to controller design, but Lab 1 follows this disciplined process all the way through (check out the table of contents!!)
#
# If we begin with modeling, we'll need to decide on something that we need to model.  We will make the choice to scope the motor.  *This is not the only choice we could make to begin*, but because we have to make a choice and the motor seems to be an important component we'll start there.
#
# To take as small a step as possible, we will chose the simplest model we can think of just to get through all the steps and then we can assess if more fidelity is needed.  A simple model doesn't need to be a mathematical model, it just has to have the ability to give you an expectation of how the motor will behave so you can make some kind of prediction.  Let's give it a try!

# %% [markdown]
# # *Model Development:* DC Motor
#
# A direct current motor uses windings of wire to generate a magnetic field which causes the *rotor* to turn when placed in a magnetic field.  As the rotor aligns with the external magnetic field, the *commutator* switches the current to a subsequent coil of wire which causes it to again rotate.  The process is repeated for every segment of the commutator causing the rotor to turn continuously.  It has been found experimentally that the torque is proportional to the current and the angular velocity is proportional to the voltage (something you discussed in Systems).
#
#
# The short video segment below animates and explains this process:

# %%
# %%html
# <iframe width="900" height="540" src="https://www.youtube.com/embed/LAtPHANEfQo?start=0&end=148" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # *Model Development:* Relay
#
# You will be using the ME480 Workstation for the semester as your "test bench" for lab experiments.  It has a motor you will control, but to operate the motor the workstation includes a relay.  You can find it on your workstation by looking at the [Workstation Layout in the Hardware Resource](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Layout) and looking for the "Safety Relay" label.
#
# This relay allows you to "turn on" power to a device, like your motor, *without* physially moving a switch.  **For safety, no power can be applied to the DC motor without first activating the relay on the ME480 workstation**, so we need to include the relay in our simple motor model.
#
# A relay is essentially an electrically actuated switch that allows you to switch a high-power circuit (such as a motor drive) using a low-power circuit (such as an Arduino).
#
# The basic information about how a relay works is provided in the short video segment below:

# %%
# %%html
# <iframe width="900" height="540" src="https://www.youtube.com/embed/n594CkrP6xE?start=107&end=229" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # *Model Development:* DC Motor & Relay
#
# Below is a circuit diagram of how the relay is connected to the motor on your workstation.
#
# ![image-5.png](attachment:image-5.png)
#
# The relay's contact is **normally open**.  This means that when the relay is NOT powered, it *breaks* the connection between the MOTOR (+) and (-) pin on the [workstation](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Layout) preventing a complete circuit and the motor from turning.
#
# The coil of the relay, which will close this connection and allow current to flow through the motor, is attached to pin 37 of the Arduino Mega allowing you to open and close the connector using Arduino code. Note some of these connections are pins you can connector a wire to, while others are built-in to the printed circuit board (PCB) as indicated on the diagram.

# %% [markdown]
# # *Model Validation:* DC Motor & Relay
#
# Although we don't have a mathematical model (such as a differential equation or transfer function) for either the relay or the motor, we do have a low fidelity model of the behavior of each.  The relay acts as a switch and the motor will move with voltage.  Although simple, it's enough to validate.

# %% [markdown]
# ## WORKSTATION SETUP
#
# 1) **Refer to the Hardware Reference to [REMOVE THE INTERTIA MODULE](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Inertia-Module)**.
#
# 2) **Install JUST THE GATE HUB (shown below) on the motor shaft.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3) **Connect the motor to the motor 1 connector plug.** While every precaution has been taken to ensure that the ME480 workstation will be robust enough for you to use all semester, it is important that you do not place undue strain on the cable wires. If you must remove a connector from one of the ports on the workstation, pull the connector out gently by grasping the plastic housing, and **do NOT pull on the wires.**
#
# ![image-3.png](attachment:image-3.png)
#
# <font color='red'>**DO NOT INSTALL THE FULL GATE**</font>, we'll just use the hub as a way to visualize what the motor is doing.
#
# <font color='red'>**DO NOT PROCEED UNTIL YOU HAVE MADE THESE CHANGES**</font>

# %% [markdown]
# ## Experimental Validation
#
# For Lab 1 we'll power the workstation and motor with the USB cable connected to your workstation and a computer.  The USB connector is [located at the front of the workstation](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Layout). The green power LED on the workstation's circuit board will be illuminated when it is powered on.
#
# You will complete the motor circuit using the breadboard, so you will need to connect the power source to the breadboard by referring to the [Hardware Resource](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Breadboard).
#
# You will need to write an Arduino program to allow the voltage to pass through the relay in order for the motor to spin!  In particular, you need to create a program that energizes the relay by setting the arduino pin to ouput 5V (HIGH) in order to close the ciruit.

# %% [markdown]
# Using the [Arduino software](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Arduino_Resource.html#Set-Up-and-Workflow), setup your board to be the "Arduino Mega 2560" (it's under your green circuit board!) and try to program the Arduino to close (energize) and open (denergize) the relay. You can use the digitalWrite() command described in the [Arduino Resource: Common Functions](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Arduino_Resource.html#Common-Functions) to change the voltage on an Arduino output pin that is connected to the relay coil.
#
# Note, that in the [diagram above](#Model-Development:-DC-Motor-&-Relay) the relay will complete the connection between Motor positive terminal to the breadboard pin `MOTOR1 (+)`, *but that will not connect the motor to a power source!*  You will need to create a complete circuit by connecting the `MOTOR1 (+)` and `MOTOR1 (-)` pins to [5V and ground buses on your breadboard](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Powering-the-Breadboard) using your jumper wires so when the relay closes the motor will be energized and you can observe it's behavior.  The gate hub will help you see the rotation when you get your motor running.
#
# <font color='red'>**BE CAREFUL THE GATE HUB DOESN'T CATCH THE MOTOR WIRES WHEN IT SPINS**</font>
#
# Once you have run and tested your code, enter it in the cell below.  To ensure your code is properly formatted and in color, include the  \~\~\~c before and \~\~\~ after your code as shown below.
#
# \~\~\~c
#
# [put code here]
#
# \~\~\~

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **In the cell below, describe the motor behavior when it is connected to a complete 5V circuit.  Also explain what happens when you change the polarity of the motor wires by changing how 5V and ground are connected to `Motor1 (-)` and `Motor1 (+)`.**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# # *Controller Design:* DC Motor Speed and Direction
#
# If you were to change the voltage connected to the DC motor you would see that as voltage increases the speed increases (you learned this relationship in Systems!).  However, we can only supply a fixed 5V to our motor with our workstation.  This is not an uncommon problem for digital systems and means we need a way to change the voltage the motor "sees" even though our voltage supply remains fixed.  Quite a conundrum!

# %% [markdown]
# ## *Model Development:* Pulse Width Modulation
#
# Since digital systems are not well suited to vary a voltage, we need to find something they CAN do well.  A digital signal **CAN** modulate a on or off very easily.  So we will modulate the signal on and off over time to adjust the AVERAGE voltage the motor recieves.
#
# This technique is called Pulse width modulation.  In this technique the **frequency of a signal is CONSTANT**, and just **the DUTY CYCLE (the % time the signal is on vs off over one period) is varied**.  The figure below shows that by
# changing the duty cycle (and NOT the fequency) the average voltage of a signal changes.
#
# ![image.png](attachment:image.png)
#
#
# If the pulse width modulated frequency is chosen to be high enough above the time constant of a system, it will "see" the PWM signal as a constant DC signal.

# %% [markdown]
# ___
# ## *Model Validation* Pulse Width Modulation
#
# As it turns out, the arduino has the ability to produce a Pulse Width Modulated (PWM) signal!  In the [Hardware Resource](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Arduino-Mega-Pin-Mapping) you will find the list of pins (listed in green) you have available to you via the socket header above the LCD screen on the Workstation circuit board. Of those pins, **pins 44 and 46 are capable of PWM.**
#
# To output a PWM you will use the ```analogWrite()``` function.  Check out how to use the function by looking at the
# [common functions list](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Arduino_Resource.html#Common-Functions) in the Arduino Resource.

# %% [markdown]
# You could measure the output of the Pin 44 on an oscilloscope to see the wave pattern, but we've created a simple simulation below to allow to perform that same experiment within the notebook.  In the simulation below, you can change the  input to the ```analogWrite()``` command and observe the change in the output.
#
# **<font color = "red">RUN THE CELL BELOW TO LAUNCH THE INTERACTIVE SIMULATION</font>**
#
# Adjust the VALUE for the ```analogWrite()``` command below and observe the change in the output signal.  If you aren't sure what the VALUE is, go back and review the ```analogWrite()``` documentation discussed above.

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

p = np.arange(0,8000,1)/1000

def f(counts):
    dc = int(counts/255.0*2000);
    y = np.zeros(2000)
    y[0:dc]=5
    y = np.hstack((y,y))
    y = np.hstack((y,y))
    return y

#plot this so we can visualize it
fig = plt.figure()
fig.canvas.toolbar_visible = False
line, = plt.step(p,f(50),'k')
plt.xlabel('time (ms)')
plt.ylabel('Volts')
plt.show()
plt.title('Arduino PWM output')

def update(VALUE = 100):
    line.set_ydata(f(VALUE))
    fig.canvas.draw_idle()
    
interact(update, VALUE = (0,255,1));
# Out:
# <img src="data:image/png;base64,..." width="150">
# interactive(children=(IntSlider(value=100, description='VALUE', max=255), Output()), _dom_classes=('widget-int…

# %% [markdown]
# **What is the amplitude and how does it change as the VALUE given to analogWrite() change?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **What is the frequency and how does it change the VALUE given to analogWrite() change?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **What is the duty cycle and how does it change the VALUE given to analogWrite() change?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **Making an "visual average" of the signal, write an *equation* relating the ```analogWrite()``` VALUE to the average voltage supplied by the PWM pin.**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# If the Arduino can output a PWM signal then it should be possible to use the signal to run the motor at different speeds... right?  Unfortunately the Arduino does not deliver enough power to drive the motor directly from its digital pins.  The Arduino outputs "signals" meaning they are very low current (40 mA) and are not intended to power anything.
#
# Lets try it!  Save a version of your previous Arduino program that activates the relay and modify it to also output an analog signal.  Use the example code as a starting point, modifying it to work with pin 44.
#
# ~~~c
# void setup() {
#   // put your setup code here, to run once.  This currently is setup to set pin 7 to output
#   pinMode(7, OUTPUT);
# }
#
# void loop() {
#   // put your main code here, to run repeatedly:
#
#     analogWrite(7,255); //this sets the PWM signal on pin 7 to 255 (the maximum amount)
# }
# ~~~
#
# Now. using jumper wires, connect **pin 44** directly to the `MOTOR 1 (+)` pin and connect the `MOTOR 1 (-)` pin to **ground**.  Now the motor circuit is being powered by pin 44 instead of directly from the 5V source.  When you run your code you should see the motor struggles to run.
#
# **This means in order to drive the motor, WE NEED A WAY TO AMPLIFY THE ARDUINO's PWM SIGNAL!**

# %% [markdown]
# ## *Model Development:* Transistor Model
#
# Bipolar junction transistors (BJT) can be used as amplifiers.  They can take in a small amount of current and turn it into a larger amount of current.  BJTs are catagorized by how their semi-conductor material is assembled.  They are constructed of $n$ material that is "doped" to have a **(n)egative** charge and $p$ material is doped to have a **(p)ositive charge**.   Arranging them in different order yields different behavior.  Here are the electrical schematic symbols for the two types of BJTs:
# <img src="attachment:image.png" width=600>

# %% [markdown]
# Here is a short video on how they work:

# %%
# %%html
#  <iframe src="https://lafayette.hosted.panopto.com/Panopto/Pages/Embed.aspx?id=06795874-6618-47e0-9e57-b137016b3b37&autoplay=false&offerviewer=true&showtitle=true&showbrand=true&captions=false&interactivity=all" height="405" width="720" style="border: 1px solid #464646;" allowfullscreen allow="autoplay" aria-label="Panopto Embedded Video Player" aria-description="ME480 Lab 1 - How transistors Work" ></iframe>
# Out:
#  <iframe src="https://lafayette.hosted.panopto.com/Panopto/Pages/Embed.aspx?id=06795874-6618-47e0-9e57-b137016b3b37&autoplay=false&offerviewer=true&showtitle=true&showbrand=true&captions=false&interactivity=all" height="405" width="720" style="border: 1px solid #464646;" allowfullscreen allow="autoplay" aria-label="Panopto Embedded Video Player" aria-description="ME480 Lab 1 - How transistors Work" ></iframe>

# %% [markdown]
# We're going to experiment with the TIP41C (npn) transistors to learn more about how to use them.  The [datasheet](https://www.mouser.com/datasheet/2/149/TIP41C-890135.pdf) contains the details of the TIP41C. It contains MUCH more information thatn you need datasheets are below.
#
# For now, we are only interested in the pinout diagram that describes which pins are the base, collector and emmiter on the datasheets. Cut and paste an image of the pin out (indicating which diagram is to which chip) in the cell below so you can have it for easy reference.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## *Model Validation:* npn Transistor
#
# To understand the behavior of an npn transitor, connect a (TIP41C) to an the motor-relay circuit on your workstation as shown below.  Use your pinout above to make sure you connect the wires to the right pins.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Read, understand and code the following program.
#
# **Modify it so it activates the relay as you did earlier allowing the transistor to control when the motor turns on.** Save the program and run it.
#
# ```c
# void setup() {
#   pinMode(44, OUTPUT);         //initialize digital pin as output
#   Serial.begin(9600);          //initialize serial port
# }
#
# void loop() {
#     digitalWrite(44, HIGH);           //set the digitial pin to HIGH (output 5V)
#     Serial.println("Pin 44 is high"); //print to the serial monitor
#     delay(1000);                      //wait 1 second
#     digitalWrite(44, LOW);            //set the digitial pin to LOW (output 0V)
#     Serial.println("Pin 44 is low");  //print to the serial monitor
#     delay(1000);
# }
# ```
#
# Use the serial monitor to confirm your program is working. Then, **in the Markdown cell below, describe the behavior of the motor when the base voltage is 0V and when the base voltage is +5V.** Is this what you expect based on your model of how a transitor works?
#
# **IF YOU AREN'T SURE WHAT TO EXPECT, CHAT WITH YOUR INSTRUCTOR.  YOU CAN'T VALIDATE A MODEL WITHOUT AN EXPECTATION!**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Based on the description of the operation of the transistors described in the video.  How would you expect the PNP to behave when you apply 0V and +5V to the base?
#
# **CHAT WITH YOUR INSTRUCTOR TO VALIDATE YOUR EXPECTATION!**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# #  *Controller Design:* H-Bridge Circuit
#
# With transistors giving us the ability turn your motor on and off from a low power "signal", we still need more capability to meet your [challenge](#Challenge) of operating the gate.  The motor will need to both open and close the gate!  So you will also need a circuit that can change the motor direction *WITHOUT* requiring you to manually disconnect and reverse the wires.
#
# The ***H-Bridge*** circuit can this jobs by using 2 npn and 2 pnp transistors arranged in an "H" shape.  Because transistors can act as an open a circuit when no current is provided to the base, they can be thought of as a type of switch.  By alternating the switches that are closed and open, the direction of the current passing though the motor can be changed and thus the direction of the motor can be changed as shown below.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #  *Controller Validation:* DC Motor Direction
#
# If we use pairs of pnp and npn BJTs we can achieve this behavior with just 2 control signals! Examine the diagram below. The NPN and PNP transistors are shown as allowing current to flow (green) and preventing current from flowing (red).
#
# ![image-7.png](attachment:image-7.png)
#
# For each case, determine the state of Pin 6 and Pin 8 (either 5V/High or 0V/LOW) that would activate the transistors as shown based on what you learned from your NPN experiment.  Copy the markdown text for this table into the cell below and complete.
#
# | Case   | Pin 6   | Pin 8  |
# |:------:|:-------:|:------:|
# | A      |         |        |
# | B      |         |        |

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# #  *Controller Validation:* DC Motor Direction
#
# Instead of building a full H-Bridge out of transistors, you will use the on H-Bridge chip [already installed on your workstation](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Layout).
#
# * To make use of the built-in H-bridge, **REMOVE ALL OF THE COMPONENTS AND WIRES YOU ADDED TO THE BREADBOARD**.  All of the connections needed to control the on-board H-Bridge are internal to the PCB.
#
# * Disconnect the motor wire connector from the MOTOR 1 socket and move it to the MOTOR 2 socket which is wired through the PCB to the H-bridge chip.
#
# You will be using the DRV8837 chip that uses Pin 6 and Pin 8 as shown in the diagrams above.  So save a version of your Arduino code from your NPN test and modify it to control both Pin 6 an Pin 8 such that it will switch between Case A and Case B.
#
# <font color = 'blue'> *Here is a tip!* </font>
# You are dealing with a lot of pins now.  Every time you want to change a pin number you have to change it in every single line where it appears in the code.  It would save you A LOT of time to use a variable instead of a number for the pin numbers.  See the example below and implement in your own code.
#
# ```c
# // the line below "declares" the name "leftPin" as an integer and a constant.
# // it is set to the value of 2
# // it is declared a constant because it is known that the value will not change when the program runs
# const int leftPin  = 2;
#
# void setup() {
#   pinMode(leftPin, OUTPUT); // initialize leftPin as an output
# }
#
# void loop() {
#   digitalWrite(leftPin, 100);
# }
# ```
#
# **When your code is working, include your properly formatted code in the cell below.**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# #  *Controller Validation:* DC Motor Speed
#
# So far the H-bridge circuit above allows you to run the motor in both directions, but you can't control the speed.  For this we'll make use of the PWM output of the Arduino by using the ```analogWrite()``` command in place of the ```digitalWrite()``` command since both transistor bases are connected to PWM capable pins on the Arduino!
#
# Save your existing Arduino code and modify it to control both direction and speed.
#
# **Proceed once you have control of speed and direction of your motor**

# %% [markdown]
# # *Model Development:* Switches
#
# Having a way to control direction and speed of a motor gives you the ability to raise and lower a gate, button meet all of the requirements of the [challenge](#Challenge) you will need to know when the gate is up and when it is down.  We'll need sensors for that job and we'll use the switches on your gate module.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# This means we need to have some model of how switches work to guide our implementation.  The switches you will need to model for this challenge on the "limit" switches installed in the gate base to detect the gate is "up" and "down".  The "momentary" buttons next to the reset button on the workstation will be used to allow the user to command the gate when to open and close.
#
# For both of these components, the electrical operation is a simple switch that closes a circuit.  On the ME480 workstation, the gate limit switches and the user input buttons are configured with one side connected to ground and the other connected to an Arduino digital pin. This corresponds to the circuit below:
#
#
# In this case, the Arduino pin should be "nominally" at 5V when the switch is open and 0V when the switch is closed.  **Let's see what actually happens!**
#
# **Install your gate module and complete gate as shown in the [Hardware Resource](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Gate-Module)**
#
# Use the code below to test your upper limit switch on your gate module.  We'll use the serial monitor to indicate if the switch is closed or if the switch is open.
#
# ~~~c
# const int upLimitSwitch  = 10;
#
# void setup() {
#   pinMode(upLimitSwitch, INPUT); // initialize the pin connected to the "up" limit switch as an input
#   Serial.begin(9600); //initialize serial communication
# }
#
# void loop() {
#   int sensorVal = digitalRead(upLimitSwitch); //read the current value of the pin connected to the limit switch
#   //sensorVal is declared as an integer
#   //in this case, it can be 1 (if the pin is at 5V) or 0 (if the pin is connected to ground)
#
#   //print sensorVal to the serial monitor so you can see it.
#   Serial.println(sensorVal);
# }
# ~~~
#
# Close and release the limit switch by manually moving the gate.  Does it change as you expect?  If it does change does it consistently show 1 and 0 as you expect? Describe whatever you see in the serial monitor in the markdown cell below.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Not sure what is going on?  Watch the short video below for an explanation of the impact of Electromagnetic Inteference (EMI).

# %%
# %%html
# <iframe width="900" height="540" src="https://www.youtube.com/embed/wxjerCHCEMg?start=95&end=187&version=3" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Having seen the need for a "pullup resistor", you'll be happy to know the Arduino has the ability to configure a digital pin to use an **internal** pull-up resistor so you don't have to add one yourself! Configuring the pins this way is as simple as one line of code.
#
# Save your arduino code and then change your pinMode command to use the INPUT_PULLUP mode:
# ~~~c
#   pinMode(upLimitSwitch, INPUT_PULLUP); // initialize the pin connected to the "up" limit switch as an input pullup
# ~~~
#
# ## *Model Validation:* Switches
#
# Try it out.  The Serial monitor output should correspond to closing and opening the switch as you expect!

# %% [markdown]
# # *Controller Design:* Parking Gate
#
# Using the understanding from above, design and implement a controller that achieves the following:
#
# * Raises and lowers the gate.
# * Stops the motor when either limit switch is pressed (**THIS IS IMPORTANT! OTHERWISE YOU WILL CAUSE HIGH CURRENT HEATING AND "BURN OUT" THE MOTOR BY OVERHEATING AND DAMAGING IT!**)
# * Uses the momentary switch **BTN 1** provided on the workstation to activate the motor.
# * If the gate-DOWN limit switch is pressed, when the momentary switch is pressed the motor will raise the gate.
# * If the gate-UP limit switch is pressed, when the momentary switch is pressed the motor will lower the gate.
# * For safety, the relay will be opened if the E-STOP button is depressed, stopping the motor no matter what other commands are provided.  Therefore the relay will be closed (allowing the motor to run) only if the E-STOP button is ***unlatched***.
#
# You can refer to the [Workstation Pin Mapping](https://sabatind.github.io/ME480_Resources/Implementation_Resources/Hardware_Resource.html#Workstation-Arduino-Mega-Pin-Mapping) to find the pins related to the buttons and switches you'll controller will need to sense.

# %% [markdown]
# **Include in the cell below a copy of your completed Arduino code including the text "\~\~\~c"  before and "\~\~\~" after the code so it is properly formatted.**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# # *Controller Validation:* Parking Gate

# %% [markdown]
# **Put a LINK to a video of your gate working in the cell below.  You can use media.lafayette.edu, youtube, vimeo, etc. to host your video**

# %% [markdown]
# YOUR ANSWER HERE
