% %% [markdown]
% <h1>Table of Contents<span class="tocSkip"></span></h1>
% <div class="toc"><ul class="toc-item"><li><span><a href="#Exercises-for-steps-1-5-of-root-locus-sketching:-Due-Friday,-October-31-by-5PM." data-toc-modified-id="Exercises-for-steps-1-5-of-root-locus-sketching:-Due-Friday,-October-31-by-5PM.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exercises for steps 1-5 of root locus sketching: Due Friday, October 31 by <em>5PM</em>.</a></span><ul class="toc-item"><li><span><a href="#Exercise-1" data-toc-modified-id="Exercise-1-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Exercise 1</a></span></li><li><span><a href="#Exercise-2" data-toc-modified-id="Exercise-2-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Exercise 2</a></span></li></ul></li></ul></div>

% %% [markdown]
% # Exercises for steps 1-5 of root locus sketching: Due Friday, October 31 by *5PM*.
%
% Sketch the root locus for the following "open loop transfer functions" $G(s)H(s)$ using steps 1 through 5 of the sketching rules. Find the crossing point and critical gain for each system if applicable. Include all hand calculations and your hand-sketch. You may check your work using Octave in the provided code cells.
%
% ## Exercise 1
%
% $$G(s)H(s) = \frac{s+20}{(s^2+20s+250)(s+1)(s+2)}$$

% %% [markdown]
% YOUR ANSWER HERE

% %%
% YOUR CODE HERE
error('No Answer Given!')

% %% [markdown]
% ## Exercise 2
%
% $$G(s)H(s) = \frac{s+10}{(s^2+20s+250)}$$

% %% [markdown]
% YOUR ANSWER HERE

% %%
% YOUR CODE HERE
error('No Answer Given!')
